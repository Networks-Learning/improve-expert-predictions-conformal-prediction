# %% [markdown]
# ## Empirical expert success probability vs. $\alpha$

# %% [markdown]
# ### Fig. 2a

# %%
from plot.plot import alpha_vs_success_synthetic_four_confs
alpha_vs_success_synthetic_four_confs(acc1=0.5, acc2=0.9)

# %% [markdown]
# ### Fig. 3a

# %%
from plot.plot import alpha_vs_success_real
alpha_vs_success_real()

# %% [markdown]
# ### Fig. 11a

# %%
from plot.plot import alpha_vs_success_real
alpha_vs_success_real(results_root='results_real_more_expressive')

# %% [markdown]
# ## Empirical average set size vs $\alpha$

# %% [markdown]
# ### Fig. 2b

# %%
from plot.plot import alpha_vs_avg_size_synthetic_four_confs

alpha_vs_avg_size_synthetic_four_confs(acc1=0.5, acc2=0.9)

# %% [markdown]
# ### Fig. 3b

# %%
from plot.plot import alpha_vs_avg_size_real

alpha_vs_avg_size_real(split=.15)

# %% [markdown]
# ### Fig 11b

# %%
from plot.plot import alpha_vs_avg_size_real
alpha_vs_avg_size_real(split=0.15, results_root='results_real_more_expressive')

# %% [markdown]
# ## Topk

# %% [markdown]
# ### Expert success probability using topk predictors with synthetic data (Fig. 8)

# %%
from plot.plot import topk_synthetic
for acc1 in [0.5, 0.9]:
    for acc2 in [0.5, 0.7, 0.9]:
        topk_synthetic(kmin=2, kmax=9, split=0.15,\
            human_accuracy=acc1, machine_accuracy=acc2, labels=10, runs=10)

# %% [markdown]
# ### Expert success probability using topk predictors with real data (Fig 9)

# %%
from plot.plot import topk_real
topk_real(split=0.15, runs=10)

# %% [markdown]
# ## Set size distribution

# %% [markdown]
# ### Set size distribution in synthetic data experiments (Fig. 10)

# %%
from plot.plot import set_size_distr_synthetic
accs = [0.5,0.7,0.9]
for human_acc in accs:
    for machine_acc in accs:
        set_size_distr_synthetic(human_acc=human_acc, machine_acc=machine_acc, split=0.15, labels=10, runs=10)

# %% [markdown]
# ## Empirical Vs. Target Coverage

# %% [markdown]
# ### Empirical vs. target coverage with synthetic data (Fig. 5a)

# %%
from plot.plot import coverage
coverage(synthetic=True, split=0.15)

# %% [markdown]
# ### Empirical vs. target coverage with real data (Fig. 5b)

# %%
from plot.plot import coverage
coverage(synthetic=False, split=0.15)

# %% [markdown]
# ## Robustness Analysis

# %% [markdown]
# ### Empirical expert success probability using our system under IIA violations in synthetic tasks (Fig. 6)

# %%
from plot.plot import robustness_synthetic

accs = [.5,.7,.9]
for human_acc in accs:
    robustness_synthetic(split=0.15, labels=10, runs=10, human_accuracy=human_acc)

# %% [markdown]
# ### Empirical expert success probability using our system under IIA violations in real data tasks (Fig. 7)

# %%
from plot.plot import robustness_real
robustness_real(split=0.15, runs=10)
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
