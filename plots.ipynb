# %% [markdown]
# # Plots appeared in paper

# %%
from plot.plot import *

# %% [markdown]
# ## Figure 2a

# %%
plot_alpha_four_confs(acc1=.5, acc2=.9)

# %% [markdown]
# ## Figure 2b

# %%
plot_size_alpha_four_confs()

# %% [markdown]
# ## Figure 3a

# %%
plot_alpha_real()

# %% [markdown]
# ## Figure 3b

# %%
plot_size_alpha_real()
